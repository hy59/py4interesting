# %%
from pylab import mpl
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('ggplot')
mpl.rcParams['font.sans-serif'] = ['SimHei']  # 解决seaborn中文字体显示问题
plt.rc('figure', figsize=(10, 10))  # 把plt默认的图片size调大一点
# 解决保存图像是负号'-'显示为方块的问题
plt.rcParams["figure.dpi"] = mpl.rcParams['axes.unicode_minus'] = False
# %matplotlib inline

# %%
place_data = pd.read_csv('data/flypig.csv',
                 names=['city', 'title', 'soldRecentNum', 'discountPrice', 'price'])

# %%
place_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58551 entries, 0 to 58550
# Data columns (total 5 columns):
# city             58551 non-null object
# title            58551 non-null object
# soldRecentNum    58551 non-null int64
# discountPrice    58551 non-null float64
# price            58551 non-null float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 2.2+ MB

# %%
place_data.sample(5)
# Out:
#       city                                title  soldRecentNum  discountPrice  \
# 7238    常州           【今日可用】常州茅山宝盛园大门票茅山宝盛园电子成人票              0           70.0
# 13532   湖州         安吉中南百草原景区 成人票电子票 含动物园植物园四大表演              0          130.0
# 55083   上海  当日可订 上海环球金融中心门票94+97+100+夜游浦江游船景点联票              3          228.0
# 5040   哈尔滨       黑龙江旅游哈尔滨松花江索道往返温泉门票特色游玩亲子游度假旅行              0          148.0
# 50037   安康      西安门票 汉江燕翔洞景区门票 汉江燕翔洞生态旅游 燕翔洞电子票             13           80.0
#
#        price
# 7238    70.0
# 13532  130.0
# 55083  228.0
# 5040   148.0
# 50037   80.0

# %% [markdown]
# # 数据清洗

# %% [markdown]
# **判断是否存在重复行，有则去除**

# %%
place_data[place_data.duplicated()]
# Out:
#       city                                 title  soldRecentNum  \
# 80     石家庄             河北石家庄黄金寨景区门票 平山黄金寨景区电子票套票              0
# 83     石家庄             荣鼎天下萌宠奇缘_石家庄萌宠奇缘门票 石家庄周边游              0
# 219    石家庄                        河北 石家庄 红崖谷 大门票              0
# 221    石家庄                        bei guo 水世界 门票              0
# 222    石家庄              bei guo shui shi jie 石家庄              0
# 223    石家庄                zhu juan gou 生态风景区 大门票              0
# 229    石家庄                      xi bu 长青水上乐园 大门票              0
# 232    石家庄                     河北 石家庄 鼎峰汗蒸世界 大门票              0
# 365    石家庄                                王母山风景区              4
# 511     唐山  kai luan 国家矿山公园 博物馆+井下探秘游+4D电影 河北 唐山              0
# 516     唐山                      唐山qing shan guan              0
# 562     唐山  kai luan 国家矿山公园 博物馆+井下探秘游+4D电影 河北 唐山              0
# 566     唐山                  河北 唐山 开滦国家矿山公园 开滦博物馆              0
# 568     唐山                        开滦国家矿山公园 井下探秘游              0
# 569     唐山                        开滦国家矿山公园 井下探秘游              0
# 684     保定                    quan sheng xia 大门票              0
# 709     保定                   he hua da guan yuan              0
# 758     保定                               狼牙山万亩花海              0
# 855    秦皇岛                             园林博览会 市民票              0
# 859    秦皇岛                             园林博览会 市民票              0
# 989    秦皇岛                         河北 秦皇岛 龙云谷 通票              0
# 1004   秦皇岛       河北 秦皇岛 北戴河联峰山公园 大门票 电子票 各旅游景区门票              0
# 1020   秦皇岛                   河北 秦皇岛 烽火台拓展俱乐部 大门票              0
# 1027   秦皇岛                  qiu xian 入海处 门票+4D电影              0
# 1040   秦皇岛               qiu xian 入海处 门票+4D电影+游船              0
# 1098   秦皇岛                        long yun gu 套票              0
# 1106   秦皇岛                    chang cheng hao 船票              0
# 1115   秦皇岛                           秦皇岛 孩子王 大门票              0
# 1118   秦皇岛                      ban chang yu 大门票              0
# 1135   秦皇岛                                 鸽子窝帆船              0
# ...    ...                                   ...            ...
# 57192   香港                          香港杜莎夫人蜡像馆大门票              0
# 57325   香港       香港杜莎夫人蜡像馆门票+太平山顶缆车+摩天台套票 香港旅游景点              0
# 57380   香港          【当天可订】香港旅游 香港海洋公园门票 亲子游含缆车套票              0
# 57417   香港    香港昂坪360缆车门票 香港昂坪360单程水晶车厢+单程标准车厢混合              0
# 57424   香港      香港 香港 昂坪360 来回缆车标准车厢 昂坪360 标准车厢L              0
# 57508   香港          当天可订|香港迪士尼乐园1日门票 迪斯尼一日票 香港旅游              0
# 57511   香港        香港新界旅游景点 马湾挪亚方舟公园 直通巴士旺角至马湾双程票              0
# 57512   香港       香港迪士尼乐园景点 1日标准门票+单程中旅汽车跨境巴士成人套票              0
# 57513   香港         香港迪士尼乐园一日门票+永东跨境快线大巴去程车票电子票套票              0
# 57523   香港          香港海洋公园门票含缆车套票 电子票套票港珠澳大桥过境巴士              0
# 57530   香港        香港太平山顶凌霄阁摩天台 太平山顶缆车 香港摩天台 香港景点              0
# 57531   香港         香港迪士尼乐园餐券/广场饭店餐券/中式午餐套餐劵/2份起订              0
# 57533   香港      景点门票 香港海洋公园门票 海洋公园+去程巴士交通 香港景点门票              0
# 57534   香港           香港迪士尼乐园酒店翠乐庭餐厅自助早餐-须与酒店一起购买              0
# 57535   香港           香港昂坪360缆车门票大屿山昂坪360水晶缆车娱乐套票              0
# 57538   香港       景点门票 香港海洋公园门票 海洋公园+去程巴士+餐劵 香港门票              0
# 57539   香港        香港海洋公园门票含缆车套票 海洋公园电子票套票成人票2日门票              0
# 57541   香港         【当天可订】香港海洋公园门票+海洋快证含缆车套票 刷码入园              0
# 57544   香港       【当天可订】香港海洋公园门票+餐券套票 含缆车票 扫码直接入园              0
# 57546   香港        香港迪士尼乐园门票2日成人儿童票+二合一餐券一餐电子票换票证              0
# 57635   香港                         香港迪士尼乐园 三合一餐券              0
# 57854   澳门        澳门塔蹦极精彩四合一（蹦极跳+高飞跳+百步登天+空中漫步）S              0
# 58032   澳门       澳门新濠天地水舞间表演门票B区+新濠影汇之星8字摩天轮电子套票              0
# 58041   澳门         即订即用 澳门巴黎人铁塔 埃菲尔铁塔观光门票 7楼和37楼              0
# 58104   澳门        澳门新濠影汇之星8字摩天轮门票八字型摩天轮旅游景点娱乐电子票              0
# 58265   澳门        澳门巴黎人埃菲尔铁塔大门票 巴黎人铁塔夜景灯光秀观光电子门票              0
# 58317   澳门       澳门新濠天地水舞间表演门票A区+巴黎人埃菲尔铁塔门票电子票套票              0
# 58319   澳门       澳门新濠天地水舞间A区门票＋新濠影汇之星8字摩天轮门票电子套票              0
# 58321   澳门       澳门新濠天地水舞间表演门票A区+威尼斯人贡多拉船船票电子票套票              0
# 58326   澳门       澳门新濠天地水舞间表演门票B区+巴黎人埃菲尔铁塔门票电子票套票              0
#
#        discountPrice   price
# 80             125.0   125.0
# 83             118.0   118.0
# 219             64.0    64.0
# 221            166.0   166.0
# 222            166.0   166.0
# 223             28.0    28.0
# 229             79.0    79.0
# 232             57.9    57.9
# 365             49.0    49.0
# 511            109.8   109.8
# 516             38.7    38.7
# 562            109.8   109.8
# 566             30.0    30.0
# 568             85.0    85.0
# 569             85.0    85.0
# 684             38.0    38.0
# 709            105.0   105.0
# 758             38.0    38.0
# 855             24.0    24.0
# 859             24.0    24.0
# 989             89.0    89.0
# 1004            25.0    25.0
# 1020            69.0    69.0
# 1027            55.0    55.0
# 1040           102.0   102.0
# 1098            89.0    89.0
# 1106            96.0    96.0
# 1115            29.9    29.9
# 1118            19.0    19.0
# 1135            90.0    90.0
# ...              ...     ...
# 57192          194.0   194.0
# 57325          275.0   275.0
# 57380          351.0   351.0
# 57417          225.0   225.0
# 57424          148.0   148.0
# 57508          493.0   493.0
# 57511           35.0    35.0
# 57512          581.0   581.0
# 57513          581.0   581.0
# 57523          347.0   347.0
# 57530           41.0    41.0
# 57531          178.0   178.0
# 57533          289.0   289.0
# 57534          300.0   300.0
# 57535          220.0   220.0
# 57538          376.0   376.0
# 57539          324.0   324.0
# 57541          517.0   517.0
# 57544          374.0   374.0
# 57546          694.0   694.0
# 57635          188.0   188.0
# 57854         5828.0  5828.0
# 58032          624.0   624.0
# 58041           59.0    59.0
# 58104           49.0    49.0
# 58265           60.0    60.0
# 58317          769.0   769.0
# 58319          769.0   769.0
# 58321          795.0   795.0
# 58326          624.0   624.0
#
# [1255 rows x 5 columns]

# %%
place_data.drop_duplicates(inplace=True)

# %%
place_data[place_data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [city, title, soldRecentNum, discountPrice, price]
# Index: []

# %% [markdown]
# **将省份与城市关联**

# %%
city_data = pd.read_csv('data/city_data.csv')

# %%
city_data.head()
# Out:
#   city province
# 0  石家庄      河北省
# 1   邯郸      河北省
# 2   唐山      河北省
# 3   保定      河北省
# 4  秦皇岛      河北省

# %%
data_final = place_data.merge(city_data, on='city')

# %%
data_final.sample(5)
# Out:
#       city                           title  soldRecentNum  discountPrice  \
# 4311    吉林           长春银河汇沐浴宾馆单人女士美体SPA套餐B              0          199.0
# 33000   深圳   【电子票 含夜场】深圳锦绣中华民俗文化村门票 锦绣中华门票             37          185.0
# 44260   成都    换花季 四川 成都 漫花庄园 大门票 电子票 大小同价票              0           35.0
# 24434   烟台  【官方现票】烟台蓬莱八仙过海门票 八仙渡门票 现票 可订当天              0           70.0
# 10661   杭州           杭州京杭大运河手工艺活态馆古法造纸亲子体验              0           45.0
#
#        price province
# 4311   199.0      吉林省
# 33000  188.0      广东省
# 44260   35.0      四川省
# 24434   70.0      山东省
# 10661   45.0      浙江省

# %% [markdown]
# # 问题
# 1. 哪些城市/省份的旅游选择最多？
# 2. 哪些城市最受游客青睐？
# 3. 最热门的景点
# 4. 各省份的好评热门景点
# 5. 很热门但是评分不好的景点
# 6. 打折力度最大的景点
# 7. 各级别景区的门票价格

# %% [markdown]
# #### 1. 哪些城市/省份的旅游选择最多？

# %%
count_city_top15 = data_final['city'].value_counts()[:15]
count_city_top15
# Out:
# 三亚    3060
# 杭州    2333
# 北京    1763
# 上海    1719
# 桂林    1660
# 广州    1594
# 厦门    1194
# 苏州    1046
# 香港    1020
# 成都     966
# 清远     920
# 重庆     860
# 常州     842
# 武汉     781
# 澳门     727
# Name: city, dtype: int64

# %%
from pyecharts import options as opts
from pyecharts.charts import Funnel, Page

funnel = (
    Funnel()
    .add("", [tuple(z) for z in zip(count_city_top15.index.tolist(),count_city_top15.values.tolist())])
    .set_global_opts(title_opts=opts.TitleOpts(title="旅游选择最多的15座城市",pos_bottom=True))
)
funnel.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="f64fba2764804d70a8e8e3db597b459c" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_f64fba2764804d70a8e8e3db597b459c = echarts.init(
#             document.getElementById('f64fba2764804d70a8e8e3db597b459c'), 'white', {renderer: 'canvas'});
#         var option_f64fba2764804d70a8e8e3db597b459c = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "funnel",
#             "data": [
#                 {
#                     "name": "\u4e09\u4e9a",
#                     "value": 3060
#                 },
#                 {
#                     "name": "\u676d\u5dde",
#                     "value": 2333
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 1763
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 1719
#                 },
#                 {
#                     "name": "\u6842\u6797",
#                     "value": 1660
#                 },
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": 1594
#                 },
#                 {
#                     "name": "\u53a6\u95e8",
#                     "value": 1194
#                 },
#                 {
#                     "name": "\u82cf\u5dde",
#                     "value": 1046
#                 },
#                 {
#                     "name": "\u9999\u6e2f",
#                     "value": 1020
#                 },
#                 {
#                     "name": "\u6210\u90fd",
#                     "value": 966
#                 },
#                 {
#                     "name": "\u6e05\u8fdc",
#                     "value": 920
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 860
#                 },
#                 {
#                     "name": "\u5e38\u5dde",
#                     "value": 842
#                 },
#                 {
#                     "name": "\u6b66\u6c49",
#                     "value": 781
#                 },
#                 {
#                     "name": "\u6fb3\u95e8",
#                     "value": 727
#                 }
#             ],
#             "sort": "descending",
#             "gap": 0,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u82cf\u5dde",
#                 "\u5317\u4eac",
#                 "\u6842\u6797",
#                 "\u53a6\u95e8",
#                 "\u6210\u90fd",
#                 "\u4e0a\u6d77",
#                 "\u91cd\u5e86",
#                 "\u5e7f\u5dde",
#                 "\u676d\u5dde",
#                 "\u5e38\u5dde",
#                 "\u6fb3\u95e8",
#                 "\u4e09\u4e9a",
#                 "\u9999\u6e2f",
#                 "\u6e05\u8fdc",
#                 "\u6b66\u6c49"
#             ],
#             "selected": {
#                 "\u4e09\u4e9a": true,
#                 "\u676d\u5dde": true,
#                 "\u5317\u4eac": true,
#                 "\u4e0a\u6d77": true,
#                 "\u6842\u6797": true,
#                 "\u5e7f\u5dde": true,
#                 "\u53a6\u95e8": true,
#                 "\u82cf\u5dde": true,
#                 "\u9999\u6e2f": true,
#                 "\u6210\u90fd": true,
#                 "\u6e05\u8fdc": true,
#                 "\u91cd\u5e86": true,
#                 "\u5e38\u5dde": true,
#                 "\u6b66\u6c49": true,
#                 "\u6fb3\u95e8": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u65c5\u6e38\u9009\u62e9\u6700\u591a\u768415\u5ea7\u57ce\u5e02",
#             "bottom": true
#         }
#     ]
# };
#         chart_f64fba2764804d70a8e8e3db597b459c.setOption(option_f64fba2764804d70a8e8e3db597b459c);
#     });
# </script>

# %%
count_province = data_final['province'].value_counts()
count_province
# Out:
# 浙江省         6098
# 广东省         5639
# 江苏省         4717
# 海南省         4063
# 山东省         3542
# 福建省         3361
# 湖北省         2661
# 广西壮族自治区     2588
# 安徽省         1908
# 北京市         1763
# 四川省         1757
# 上海市         1719
# 云南省         1706
# 河北省         1663
# 辽宁省         1622
# 江西省         1427
# 河南省         1396
# 陕西省         1377
# 香港          1020
# 湖南省          989
# 甘肃省          867
# 重庆市          860
# 澳门           727
# 黑龙江省         708
# 贵州省          566
# 吉林省          502
# 山西省          460
# 天津市          453
# 宁夏回族自治区      330
# 内蒙古自治区       265
# 西藏自治区        188
# 台湾           156
# 新疆维吾尔自治区     151
# 青海省           47
# Name: province, dtype: int64

# %%
province = [pro.replace('省', '') for pro in list(count_province.index)]
province = [pro.replace('市', '') for pro in province]
province = [pro.replace('新疆维吾尔自治区', '新疆') for pro in province]
province = [pro.replace('宁夏回族自治区', '宁夏') for pro in province]
province = [pro.replace('内蒙古自治区', '内蒙古') for pro in province]
province = [pro.replace('西藏自治区', '西藏') for pro in province]
province = [pro.replace('广西壮族自治区', '广西') for pro in province]
province
# Out:
# ['浙江',
#  '广东',
#  '江苏',
#  '海南',
#  '山东',
#  '福建',
#  '湖北',
#  '广西',
#  '安徽',
#  '北京',
#  '四川',
#  '上海',
#  '云南',
#  '河北',
#  '辽宁',
#  '江西',
#  '河南',
#  '陕西',
#  '香港',
#  '湖南',
#  '甘肃',
#  '重庆',
#  '澳门',
#  '黑龙江',
#  '贵州',
#  '吉林',
#  '山西',
#  '天津',
#  '宁夏',
#  '内蒙古',
#  '西藏',
#  '台湾',
#  '新疆',
#  '青海']

# %%
from pyecharts import options as opts
from pyecharts.charts import Map

map = (
    Map()
    .add("", [tuple(z) for z in zip(province, count_province.tolist())], "china")
    .set_global_opts(
        title_opts=opts.TitleOpts(title="全国各省份旅游选择数量图"),
        visualmap_opts=opts.VisualMapOpts(max_=6500, is_piecewise=True),
    )
)


map.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#     <div id="6f6f039085144893ac880d6115205d4e" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts', 'china'], function(echarts) {
#         var chart_6f6f039085144893ac880d6115205d4e = echarts.init(
#             document.getElementById('6f6f039085144893ac880d6115205d4e'), 'white', {renderer: 'canvas'});
#         var option_6f6f039085144893ac880d6115205d4e = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 6098
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 5639
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 4717
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 4063
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 3542
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 3361
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 2661
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 2588
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 1908
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 1763
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 1757
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 1719
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 1706
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 1663
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 1622
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 1427
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 1396
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 1377
#                 },
#                 {
#                     "name": "\u9999\u6e2f",
#                     "value": 1020
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 989
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 867
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 860
#                 },
#                 {
#                     "name": "\u6fb3\u95e8",
#                     "value": 727
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 708
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 566
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 502
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 460
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 453
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 330
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 265
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 188
#                 },
#                 {
#                     "name": "\u53f0\u6e7e",
#                     "value": 156
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 151
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 47
#                 }
#             ],
#             "roam": true,
#             "zoom": 1,
#             "showLegendSymbol": true
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u5168\u56fd\u5404\u7701\u4efd\u65c5\u6e38\u9009\u62e9\u6570\u91cf\u56fe"
#         }
#     ],
#     "visualMap": {
#         "type": "piecewise",
#         "min": 0,
#         "max": 6500,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true
#     }
# };
#         chart_6f6f039085144893ac880d6115205d4e.setOption(option_6f6f039085144893ac880d6115205d4e);
#     });
# </script>

# %% [markdown]
# #### 2. 哪些城市最受游客青睐？

# %%
city_sale_top10 = data_final.groupby('city')['soldRecentNum'].sum().nlargest(10)
city_sale_top10
# Out:
# city
# 上海    456346
# 北京    196538
# 广州    187137
# 杭州    183442
# 香港    178075
# 成都     79245
# 武汉     67638
# 苏州     63906
# 西安     63220
# 南京     61491
# Name: soldRecentNum, dtype: int64

# %%
from pyecharts.charts import Bar
from pyecharts import options as opts
bar = (
    Bar()
    .add_xaxis(list(city_sale_top10.index))
    .add_yaxis("", city_sale_top10.tolist())
    .reversal_axis()
    .set_series_opts(label_opts=opts.LabelOpts(position="right"))
    .set_global_opts(title_opts=opts.TitleOpts(title="最近一个月售出门票Top10城市"))
)
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="2a56a324751f4832a1f97995358a673d" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_2a56a324751f4832a1f97995358a673d = echarts.init(
#             document.getElementById('2a56a324751f4832a1f97995358a673d'), 'white', {renderer: 'canvas'});
#         var option_2a56a324751f4832a1f97995358a673d = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "data": [
#                 456346,
#                 196538,
#                 187137,
#                 183442,
#                 178075,
#                 79245,
#                 67638,
#                 63906,
#                 63220,
#                 61491
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u4e0a\u6d77",
#                 "\u5317\u4eac",
#                 "\u5e7f\u5dde",
#                 "\u676d\u5dde",
#                 "\u9999\u6e2f",
#                 "\u6210\u90fd",
#                 "\u6b66\u6c49",
#                 "\u82cf\u5dde",
#                 "\u897f\u5b89",
#                 "\u5357\u4eac"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "text": "\u6700\u8fd1\u4e00\u4e2a\u6708\u552e\u51fa\u95e8\u7968Top10\u57ce\u5e02"
#         }
#     ]
# };
#         chart_2a56a324751f4832a1f97995358a673d.setOption(option_2a56a324751f4832a1f97995358a673d);
#     });
# </script>
